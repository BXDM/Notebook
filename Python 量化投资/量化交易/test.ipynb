# %%
import matplotlib.pyplot as plt

# Create a figure and axis for the plot
plt.figure(figsize=(14, 7))

# Plotting the Close price, Short-term Moving Average, and Long-term Moving Average
plt.plot(data.index, data['Close'], label='Close Price', color='blue')
plt.plot(data.index, data['Short_MA'], label='20-Day SMA', color='red')
plt.plot(data.index, data['Long_MA'], label='50-Day SMA', color='green')

# Adding legend to the plot
plt.legend()

# Optional: Adding title and labels
plt.title('MSFT Close Price and Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')

# Display the plot
plt.show()
