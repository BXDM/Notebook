# %%
import pandas as pd

# 定义Nasdaq的URL
nasdaq_url = 'https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&render=download'

# 使用pandas读取数据
nasdaq_data = pd.read_csv(nasdaq_url)

# 查看数据
print(nasdaq_data.head())

# 保存数据到本地文件
nasdaq_data.to_csv('nasdaq_stocks.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[1], line 7
#       4 nasdaq_url = 'https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&render=download'
#       6 # 使用pandas读取数据
# ----> 7 nasdaq_data = pd.read_csv(nasdaq_url)
#       9 # 查看数据
#      10 print(nasdaq_data.head())
#
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="market-hkex" data-wf-page="5e37e0bcc62330e0912344e8" lang="en" prefix="og: http://ogp.me/ns#" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head><title>
# 	Equities
# </title><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/assets/images/favicon.png" rel="shortcut icon" type="image/x-icon"/><link href="/assets/images/webclip.png" rel="apple-touch-icon"/>
# <!-- Seo Meta Tag Component -->
# <meta content="list of securities, stock quote, stock look up , stock lookup, top 5, top 10, most traded stocks, hong kong listed companies, hong kong stocks" name="keywords"/>
# <meta content="Full list of securities with turnover and market cap information." name="description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
# 查找公司列表
table = soup.find('table', {'class': 'table'})
rows = table.find_all('tr')

# 提取表格中的数据
companies = []
for row in rows[1:]:  # 跳过表头
    cols = row.find_all('td')
    company = {
        'Stock Code': cols[0].text.strip(),
        'Company Name': cols[1].text.strip(),
        'Category': cols[2].text.strip(),
    }
    companies.append(company)

# 创建DataFrame
companies_df = pd.DataFrame(companies)

# 显示获取到的公司名单
print(companies_df)

# 保存公司名单到CSV文件
companies_df.to_csv('hkex_listed_companies.csv', index=False)
