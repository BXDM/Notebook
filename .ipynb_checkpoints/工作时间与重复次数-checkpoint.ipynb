# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

t1 = 5
a = 3
b = 0.95
x = np.linspace(0, 1000, 1000)
temp = np.log(b)/np.log(a)

# %% [markdown]
# $ t_x = t_1x^{\frac{\log{b}}{\log{a}}} $

# %%
tx = t1*(x**temp)
# Out:
# <ipython-input-37-c250eed28037>:1: RuntimeWarning: divide by zero encountered in power
#   tx = t1*(x**temp)

# %%
plt.plot(x, tx)
plt.grid()
