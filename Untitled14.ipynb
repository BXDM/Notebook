# %%
# 机械硬盘的正常使用寿命 60 万小时
60 * 10000/24/365
# Out:
# 68.4931506849315

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 100, 100)
y1 = x**2
y2 = x**3
y3 = x*np.sin(x)+np.cos(x)

# %%
plt.plot(x, y3)
#plt.xlim(0,20)
