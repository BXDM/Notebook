# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 100)

# %%
plt.plot(x, np.sin(2*x))

# %%
mu = 4*np.pi*10e-7

# %%
np.sqrt(1/(np.pi*mu))
# Out:
# 159.15494309189535

# %%
np.sqrt(10)/(2*np.pi)
# Out:
# 0.5032921210448704
