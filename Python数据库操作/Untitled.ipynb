# %%
import pandas as pd
import sqlite3

# %%
file = r'F:\代码文件\SQL\test.db'

# %%
db = sqlite3.connect(file)

# %%
c = db.cursor() # 创建游标 cursor

# %%
# 查看表名
c.execute("SELECT NAME FROM sqlite_master WHERE type='table';")
Tables = c.fetchall()
print(Tables)
# Out:
# [('Accidents0515',), ('Casualties0515',), ('Vehicles0515',)]

# %%
# Pandas 读取 SQL 数据

# %%
idx = '\'527350\''

# %%
sql = 'SELECT * FROM Accidents0515 WHERE Location_Easting_OSGR ='  + idx
sql
# Out:
# "SELECT * FROM Accidents0515 WHERE Location_Easting_OSGR ='527350'"

# %%
sql2 = 'SELECT * FROM Accidents0515'

# %%
accd = pd.read_sql(sql, con = db)
len(accd)
# Out:
# 158

# %%
accd
# Out:
#         Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0        200501BS00001               525680.0                178240.0
# 1        200501BS00002               524170.0                181650.0
# 2        200501BS00003               524520.0                182240.0
# 3        200501BS00004               526900.0                177530.0
# 4        200501BS00005               528060.0                179040.0
# ...                ...                    ...                     ...
# 1780648  2015984139115               312087.0                570791.0
# 1780649  2015984139715               320671.0                569791.0
# 1780650  2015984140215               311731.0                586343.0
# 1780651  2015984140515               328273.0                570137.0
# 1780652  2015984141415               314050.0                579638.0
#
#          Longitude   Latitude  Police_Force  Accident_Severity  \
# ...

# %%
accd[['Location_Easting_OSGR', 'Location_Northing_OSGR']].plot()
# Out:
# <AxesSubplot:>

# %%
for i in range(len(accd.columns)):
    print(accd.columns[i])
# Out:
# Accident_Index
# Location_Easting_OSGR
# Location_Northing_OSGR
# Longitude
# Latitude
# Police_Force
# Accident_Severity
# Number_of_Vehicles
# Number_of_Casualties
# Date
# Day_of_Week
# Time
# Local_Authority_(District)
# Local_Authority_(Highway)
# 1st_Road_Class
# 1st_Road_Number
# Road_Type
# Speed_limit
# Junction_Detail
# Junction_Control
# 2nd_Road_Class
# 2nd_Road_Number
# Pedestrian_Crossing-Human_Control
# Pedestrian_Crossing-Physical_Facilities
# Light_Conditions
# Weather_Conditions
# Road_Surface_Conditions
# Special_Conditions_at_Site
# Carriageway_Hazards
# Urban_or_Rural_Area
# Did_Police_Officer_Attend_Scene_of_Accident
# LSOA_of_Accident_Location

# %%
# Out:
# RangeIndex(start=0, stop=158, step=1)
