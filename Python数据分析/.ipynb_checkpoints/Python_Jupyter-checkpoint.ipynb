# %%
# 参考资料 book 《 python for data analysis 》 page 25

# %%
# %run ipython_script_test.py
# 使用 % 运行本地的脚本,没有空格

# %%
c
# Out:
# 7.5

# %%
result
# Out:
# 1.4666666666666666

# %%
# %matplotlib inline
# 在 notebook 中画图

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.random.randn(50).cumsum())
# cumus：累积和
