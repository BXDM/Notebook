# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x  = np.linspace(-100, 100, 100)

# %%
y = np.random.randn(100)

# %%
plt.plot(x,y)

# %%
# colors = np.zeros(colors_bool.size, dtype = "U1")
# colors[:] = 'green'
# for i in range(len(x)):
#     colors_bool = y[i] >= y[i-1]
#     colors[colors_bool] = 'white'

# %%
x = 1, 3, 5, 10, 32

# %%
y = 16, 8, 20, 3, 7

# %%
plt.plot(x, y, color = "black", linestyle = "--",
        linewidth = 1.8, label = "open", alpha = 0.5)
for i in range(len(x)):
    plt.bar(x, y[i] - y[i-1])

# %%
plt.plot(x, y, color = "black", linestyle = "--",
        linewidth = 1.8, label = "open", alpha = 0.5)
for i in range(len(x)):
    plt.bar(x, y[i] - y[i-1])

# %% [markdown]
# 参考资料：[Python matplotlib 绘制K线图（蜡烛图）](https://blog.csdn.net/weixin_45875105/article/details/107221233)

# %%
import pandas as pd

# %%
# 读取文件
file = 'aapl.csv'
data = pd.read_csv(file, header = None)

# %%
data.head(3)
# Out:
#       0           1  2       3       4       5       6         7
# 0  AAPL  28-01-2011     344.17  344.40  333.53  336.10  21144800
# 1  AAPL  31-01-2011     335.80  340.04  334.30  339.32  13473000
# 2  AAPL  01-02-2011     341.30  345.65  340.98  345.03  15236800

# %%
x = [1, 1]
y = [2, 3]
plt.plot(x, y)
