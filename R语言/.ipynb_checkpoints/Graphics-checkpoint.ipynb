# %%
library(nutshell)

# %%
data(yosemite)

# %%
dim(yosemite)
# Out:
# [1] 562 253

# %%
contour(yosemite, asp = 253/562, ylim = c(1, 0))
# Out:
# plot without title

# %%
yosemite.flipped <- yosemite[, seq(from = 253, to = 1)]
yosemite.rightmost <- yosemite[nrow(yosemite) - ncol(yosemite) + 1,]
halfdome <- yosemite[(nrow(yosemite) - ncol(yosemite) + 1):562, 
                    seq(from = 253, to = 1)]

# %%
persp(halfdome, col = grey(0.75), border = NA, expand = 0.15, 
     theta = 225, phi = 20, ltheta = 45, lphi = 20, shade = 0.75)
# Out:
# plot without title
