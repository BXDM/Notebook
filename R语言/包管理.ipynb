# %% [markdown]
# 从源码安装包
#
# ```r
# install.packages(path_to_file, repos = NULL, type="source")
# ```
# [stackoverflow 参考资料](https://stackoverflow.com/questions/1474081/how-do-i-install-an-r-package-from-source)

# %%
# 列出本地库中的包

# %%
# 列出自定加载的包
getOption("defaultPackages")
# Out:
# [1] "datasets"  "utils"     "grDevices" "graphics"  "stats"     "methods"

# %%
# 查看已经安装的 R 包
(.packages(all.available = TRUE))
# Out:
#   [1] "colorspace"   "crayon"       "devtools"     "digest"       "evaluate"
#   [6] "farver"       "ggplot2"      "gtable"       "IRdisplay"    "IRkernel"
#  [11] "isoband"      "labeling"     "munsell"      "pbdZMQ"       "RColorBrewer"
#  [16] "repr"         "RODBC"        "scales"       "uuid"         "viridisLite"
#  [21] "askpass"      "assertthat"   "backports"    "base"         "base64enc"
#  [26] "BH"           "boot"         "brew"         "callr"        "class"
#  [31] "cli"          "clipr"        "cluster"      "codetools"    "commonmark"
#  [36] "compiler"     "covr"         "crosstalk"    "curl"         "datasets"
#  [41] "desc"         "DT"           "ellipsis"     "fansi"        "foreign"
#  [46] "fs"           "gh"           "git2r"        "glue"         "graphics"
#  [51] "grDevices"    "grid"         "highr"        "htmltools"    "htmlwidgets"
#  [56] "httr"         "ini"          "jsonlite"     "KernSmooth"   "knitr"
#  [61] "later"        "lattice"      "lazyeval"     "lifecycle"    "magrittr"
#  [66] "markdown"     "MASS"         "Matrix"       "memoise"      "methods"
#  [71] "mgcv"         "mime"         "nlme"         "nnet"         "openssl"
#  [76] "parallel"     "pillar"       "pkgbuild"     "pkgconfig"    "pkgload"
#  [81] "praise"       "prettyunits"  "processx"     "promises"     "ps"
#  [86] "purrr"        "R6"           "rcmdcheck"    "Rcpp"         "rematch2"
#  [91] "remotes"      "rex"          "rlang"        "roxygen2"     "rpart"
#  [96] "rprojroot"    "rstudioapi"   "rversions"    "sessioninfo"  "spatial"
# [101] "splines"      "stats"        "stats4"       "stringi"      "stringr"
# [106] "survival"     "sys"          "tcltk"        "testthat"     "tibble"
# [111] "tools"        "translations" "usethis"      "utf8"         "utils"
# [116] "vctrs"        "whisker"      "withr"        "xfun"         "xml2"
# [121] "xopen"        "yaml"

# %%
# 加载包
library(ggplot2)
